# %%
from functions.cargar_data import cargar_data_eda

# %%
censo, pbi, md, deptos, localidad, centro_pobl, capital = cargar_data_eda()
# Out:
# (         DPTO  LOC  SECC  SEGM  PERPH02  PERNA01     PERNA02  PERMI01  \
#  0           1   20     1     1        2     22.0  1988-11-01        1
#  1           1   20     1     1        2     84.0  1927-07-01        1
#  2           1   20     1     1        1     21.0  1990-07-01        1
#  3           1   20     1     1        2      0.0  2011-08-01        1
#  4           1   20     1     1        2     31.0  1980-02-01        3
#  ...       ...  ...   ...   ...      ...      ...         ...      ...
#  3285872    19  971     3   404        1     34.0  1976-12-01        3
#  3285873    19  971     3   404        1     58.0  1953-09-01        3
#  3285874    19  971     3   404        1     58.0  1953-01-01        2
#  3285875    19  971     3   404        1     20.0  1991-09-01        3
#  3285876    19  971     3   404        1     22.0  1989-04-01        1
#
#           PERMI01_1  PERMI01_2  ...  PERED02_4  PERED03_R  PERED03_1  \
# ...
