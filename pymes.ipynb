# %%
import pandas as pd

# %%
filepath = 'datos_pymes/Marco_Mpymes_2020.zip'

pymes = pd.read_csv(filepath, sep='\t')

pymes = pymes.loc[pymes.NOMBRE_DEPARTAMENTO != 'SIN CODIFICAR']

pymes.head(1)
# Out:
# c:\Users\59898\anaconda3\envs\tesis\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             RUT           NOMBRE_EMPRESA             RAZON_SOCIAL  \
# 0  216573380014  RENCOI SOCIEDAD ANONIMA  RENCOI SOCIEDAD ANONIMA
#
#   NOMBRE_CALLE  NRO_PUERTA BIS_EMP APTO_EMP NOMBRE_LOCALIDAD  \
# 0    HERVIDERO         0.0     NaN      NaN            YOUNG
#
#   NOMBRE_DEPARTAMENTO  TELEFONO_1 TELECONO_2 NATURALEZA_JURIDICA SECCION  \
# 0           RIO NEGRO         NaN  9005866.0    SOCIEDAD ANONIMA       G
#
#     CIIU                            DESCRIPCION CIIU REV. 4  MPYMES  \
# 0  45101  Importacion de vehiculos automotores: comercio...       1
#
#     TRAMO_MPYMES
# 0  MICRO EMPRESA

# %%
pymes.shape
# Out:
# (190238, 17)

# %%
len(pymes.RUT.unique())
# Out:
# 190238

# %%
pymes.columns
# Out:
# Index(['RUT', 'NOMBRE_EMPRESA', 'RAZON_SOCIAL', 'NOMBRE_CALLE', 'NRO_PUERTA',
#        'BIS_EMP', 'APTO_EMP', 'NOMBRE_LOCALIDAD', 'NOMBRE_DEPARTAMENTO',
#        'TELEFONO_1', 'TELECONO_2', 'NATURALEZA_JURIDICA', 'SECCION', 'CIIU',
#        'DESCRIPCION CIIU REV. 4', 'MPYMES', 'TRAMO_MPYMES'],
#       dtype='object')

# %%
ct = pd.crosstab(pymes.NOMBRE_DEPARTAMENTO, pymes.SECCION)
ct
# Out:
# SECCION                A   B     C   D    E     F      G      H     I     J  \
# NOMBRE_DEPARTAMENTO
# ARTIGAS               36  65   279   0    8    97   1175    291    98    45
# CANELONES            225  45  2570   2   69  1360   8557   2189  1014   586
# CERRO LARGO           53   3   275   1    5   109   1415    291   115    38
# COLONIA              121  20   865   3   24   332   3108    835   523   126
# DURAZNO               59   7   204   1    5   101   1135    206   119    45
# FLORES                31   3    99   4    3    63    529    132    59    20
# FLORIDA               53  11   360   0    6   181   1446    346   125    57
# LAVALLEJA             78  12   260   1    5   116   1146    220   135    32
# MALDONADO            118  22  1005   5   25   929   3777    847  1078   241
# MONTEVIDEO           256  23  7583  24  406  3820  24743  12584  3037  4604
# PAYSANDU              59   4   611   1   13   263   2439    566   212    95
# ...

# %%
ct['total'] = pymes.groupby('NOMBRE_DEPARTAMENTO').size().values

ct.to_csv('tablas/mypymes.csv')
