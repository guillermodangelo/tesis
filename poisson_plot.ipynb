# %%
from scipy.stats import poisson 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# creating a numy array for x-axis 
x = np.arange(0, 30, 0.5) 
  
# poisson distribution data for y-axis 
y = poisson.pmf(x, mu=.05, loc=10) 
  
plt.plot(x, y) 
plt.show()
